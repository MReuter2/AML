# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 6th exercise: <font color="#C70039">Work with Autoencoders for anomaly detection</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: Marvin Reuter
# * Matriculation number: 11139466
# * Date:   10.11.2024
#
# <img src="https://blog.keras.io/img/ae/autoencoder_schema.jpg" style="float: center;" width="700">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# Autoencoder is an unsupervised artificial neural network (ANN) that learns how to efficiently compress and encode data and then learns how to reconstruct the data back from the reduced encoded representation to a representation that is as close to the original input as possible.
#
# An Autoencoder reduces data dimensions by learning how to ignore the noise in the data and thus outliers.
# In the section above, you can seen an example of the input/output image from the MNIST dataset to an Autoencoder.
#
# #### Autoencoder Components:
# An Autoencoder consists of four main parts:
#
# 1. Encoder: In which the model learns how to reduce the input dimensions and compress the input data into an encoded representation.
#
# 2. Bottleneck: which is the layer that contains the compressed representation of the input data. This is the lowest possible dimensions of the input data. The bottlneck is also called latent vector. The concept of the latent space and latent vectors becomes important later on as we move forward to understand Generative Models.
#
# 3. Decoder: In which the model learns how to reconstruct the data from the encoded representation to be as close to the original input as possible.
#
# 4. Reconstruction Loss: This is the method that measures how well the decoder is performing and how close the output is to the original input.
#
# As always in ANNs, the training itself involves back propagation in order to minimize the network’s reconstruction loss.
#
# Due to this features of an Autoencoder the use cases are manyfold. One of the obviously is anomaly detection.
#
# #### Autoencoder Architecture:
#
# The network architecture for Autoencoders can vary between simple Feed Forward networks, Recurrent Neural Networks (LSTM) or Convolutional Neural Networks (CNN) depending on the use case.
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments whereever you feel it necessary for better understanding
#     * run the notebook for the first time.
#     * the example below shows how to use an autoencoder for anomaly detection
#
# 4. <font color=green>Develop an Autoencoder for Domain Adaptation (Me -> Walter White ). You can of course also take own data, e.g. a photo of yours and someone else.</font>
# 5. Set at least the following hyperparameters for training (epochs=100000, shuffle=True).
# 6. Implement a CNN for working out important features for the adaptation. If you feel lost in the exercise, please visit the sample solution.
# 7. There is also an implementation of data augmentation that helps you building up your data set from one single "original" image.
# ---------------------------------

# %% [markdown]
# ### Auto-Encoding
# If you have correlated input data, the auto-encoder method will work very well because the encoding operation relies on the correlated features to compress the data.
# Let’s consider that an auto-encoder is trained on the MNIST dataset.
# As you know already, using a simple FeedForward neural network, this can be done by building a simple 6 layers network as below:

# %%
import numpy as np
import keras
from   keras.datasets import mnist
from   keras.models import Sequential, Model
from   keras.layers import Dense, Input
from   keras import optimizers
from   keras.optimizers import Adam

# load the inbuild mnist data set (8bit grayscale digits)
# https://en.wikipedia.org/wiki/MNIST_database
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# normalize the training and the validation data set
train_x = x_train.reshape(60000, 784) / 255
val_x = x_test.reshape(10000, 784) / 255

# build the auto-encoding layers
autoencoder = Sequential()
autoencoder.add(Dense(512,  activation='elu', input_shape=(784,)))
autoencoder.add(Dense(128,  activation='elu'))
autoencoder.add(Dense(10,   activation='linear', name="bottleneck"))
autoencoder.add(Dense(128,  activation='elu'))
autoencoder.add(Dense(512,  activation='elu'))
autoencoder.add(Dense(784,  activation='sigmoid'))
autoencoder.compile(loss='mean_squared_error', optimizer = Adam())

'''
NOTE:
-----
The Exponential Linear Unit (ELU) is an activation function for neural networks. 
In contrast to ReLUs (which you know), ELUs have negative values which allows them to push mean unit 
activations closer to zero like batch normalization but with lower computational complexity.
'''    

# train the model and finally assign the encoding to the decoder
'''
NOTE:
-----
make sure you understand, that you are training on train_x and not on train_y but train_x again for the reconstruction
the same for the validation (val_x, val_x)
'''
trained_model = autoencoder.fit(train_x, train_x, batch_size=1024, epochs=10, verbose=1, validation_data=(val_x, val_x))
encoder = Model(autoencoder.input, autoencoder.get_layer('bottleneck').output)

encoded_data = encoder.predict(train_x)  # bottleneck representation

decoded_output = autoencoder.predict(train_x)        # reconstruction
encoding_dim = 10

# return the decoder
encoded_input = Input(shape=(encoding_dim,))
decoder = autoencoder.layers[-3](encoded_input)
decoder = autoencoder.layers[-2](decoder)
decoder = autoencoder.layers[-1](decoder)
decoder = Model(encoded_input, decoder)
# Out:
# Epoch 1/10
# 59/59 [==============================] - 2s 28ms/step - loss: 0.0756 - val_loss: 0.0504
# Epoch 2/10
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0432 - val_loss: 0.0363
# Epoch 3/10
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0327 - val_loss: 0.0294
# Epoch 4/10
# 59/59 [==============================] - 2s 26ms/step - loss: 0.0279 - val_loss: 0.0258
# Epoch 5/10
# 59/59 [==============================] - 1s 23ms/step - loss: 0.0251 - val_loss: 0.0238
# Epoch 6/10
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0234 - val_loss: 0.0223
# Epoch 7/10
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 8/10
# 59/59 [==============================] - 2s 25ms/step - loss: 0.0210 - val_loss: 0.0202
# Epoch 9/10
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0202 - val_loss: 0.0195
# Epoch 10/10
# 59/59 [==============================] - 1s 24ms/step - loss: 0.0195 - val_loss: 0.0189
# 1875/1875 [==============================] - 2s 1ms/step
# 1875/1875 [==============================] - 3s 2ms/step

# %% [markdown]
# As you can see in the output, the last reconstruction loss/error for the validation set is approx. 0.0197, which is great.
# Now, if we pass any normal image from the MNIST dataset, the reconstruction loss will be very low (< 0.02) BUT if we tried to pass any other different image (outlier / anomaly), we will get a high reconstruction loss value because the network failed to reconstruct the image/input that is considered an anomaly.
#
# Notice in the code above, you can use only the encoder part to compress some data or images and you can also only use the decoder part to decompress the data by loading the decoder layers.

# %% [markdown]
# #### Auto-Encoders for Anomaly Detection
# Now, let’s do some anomaly detection. The code below uses two different images to predict the anomaly score (reconstruction error) using the autoencoder network we trained above.
#
# The first image is from the MNIST and the result is error=2.46241018. This means that the image is not an anomaly. The second image (yoda.png) obviously does not belong to the training dataset and the result is: error=2727.0718. This high error means that the image is an anomaly. Even the third image. The same concept applies to any type of dataset.

# %%
# If you are using a newer version of keras than '2.4.3', read this article below.
# It describes a versioning issue in the keras libs
'''https://stackoverflow.com/questions/72383347/how-to-fix-it-attributeerror-module-keras-preprocessing-image-has-no-attribu'''
#from keras.preprocessing import image
from keras.utils import load_img, img_to_array

# take an image from the validation data set or the training data set, respectively
input_img = val_x[50] 
input_img_flat = input_img.reshape(1,784)

target_data = autoencoder.predict(input_img_flat)

dist = np.linalg.norm(input_img_flat - target_data, axis=-1)

print(dist)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# [2.42285825]

# %%
# Now take Master Yoda as the test image. The error score will be very high (error=2727.0718)
img = load_img("./data/yoda.png", target_size=(28, 28), color_mode = "grayscale")
input_img = img_to_array(img)

input_img_flat = input_img.reshape(1,784)
target_data = autoencoder.predict(input_img_flat)
dist = np.linalg.norm(input_img_flat - target_data, axis=-1)
print(dist)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [2726.7202]

# %%
''' 
Now take a Mnist image which is taken from the google image search and although it is super similar to the training data
it does not belong to the same data distribution the auto-encoder was trained on. 
It produces an error almost as high as yoda.png (approx error=2551.99)
This makes autoencoders being a very robust technique for anomaly detection.
'''
img = load_img("./data/similarMnistNumber.jpg", target_size=(28, 28), color_mode = "grayscale")
input_img = img_to_array(img)

input_img_flat = input_img.reshape(1,784)
target_data = autoencoder.predict(input_img_flat)
dist = np.linalg.norm(input_img_flat - target_data, axis=-1)

print(dist)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [2551.912]

# %% [markdown]
# #### Auto Encoder for Domain Adaption

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential
import os
from   tqdm import tqdm
import time

SIZE=256

# %%
# import input img (original Gernot Heisenberg)
input_img_data=[]
input_path = './data/heisenberg_heisenberg/gernot/'
files=os.listdir(input_path)
# read all images in the folder (different rotations and flips of the original)
for i in tqdm(files):
    img=cv2.imread(input_path+'/'+i,1)   #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    input_img_data.append(img_to_array(img))
# -----------------------------------------  
# import output_img (Walter White)
output_img_data=[]
output_path = './data/heisenberg_heisenberg/walter/'
files=os.listdir(output_path)
# read all images in the folder (same rotations and flips as img)
for i in tqdm(files):
    img=cv2.imread(output_path+'/'+i,1)  #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    output_img_data.append(img_to_array(img))

# reshape and normalize -> every image is in the same format
input_img_array = np.reshape(input_img_data, (len(input_img_data), SIZE, SIZE, 3))
input_img_array = input_img_array.astype('float32') / 255. # normalize
output_img_array= np.reshape(output_img_data, (len(output_img_data), SIZE, SIZE, 3))
output_img_array = output_img_array.astype('float32') / 255. # normalize

# Original image for prediction of output_img (not rotate and in the original "style"
# this one does not belong to the training set
test_img_data=[]

test_img=cv2.imread('./data/heisenberg_heisenberg/gernot-heisenberg-original.jpg', 1)   #Change 0 to 1 for color images
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)#Changing BGR to RGB to show images in true colors
test_img=cv2.resize(test_img,(SIZE, SIZE))
test_img_data.append(img_to_array(test_img))

test_img_array = np.reshape(test_img_data, (len(test_img_data), SIZE, SIZE, 3))
test_img_array = test_img_array.astype('float32') / 255. # normalize

# set the start time
# later needed for calculating the computation time
start=time.time()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 564.10it/s]
# 100%|██████████| 50/50 [00:00<00:00, 607.61it/s]

# %%
# build the autoencoder model (CNN)

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
     
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 8)       2312
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 8)         584
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 8)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 8)         584
#
#  up_sampling2d (UpSampling2D  (None, 64, 64, 8)        0
#  )
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 8)         584
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 8)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)      2336
#
#  up_sampling2d_2 (UpSampling  (None, 256, 256, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 3)       867
#
# =================================================================
# Total params: 8,163
# Trainable params: 8,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model of input_img to output_img (min 100.000 epochs)
epochs = 50000
model.fit(input_img_array, output_img_array, epochs=epochs, shuffle=True)

# print out the computation time
finish=time.time()
print('total computation time = ', finish-start)

# save the model
model.save("domain_adapt_autoenc_epochs." + str(epochs) + ".keras")
# Out:
# Epoch 1/50000
# 2/2 [==============================] - 3s 657ms/step - loss: 0.1465 - accuracy: 0.0693
# Epoch 2/50000
# 2/2 [==============================] - 2s 636ms/step - loss: 0.1234 - accuracy: 0.0679
# Epoch 3/50000
# 2/2 [==============================] - 2s 711ms/step - loss: 0.1092 - accuracy: 0.1446
# Epoch 4/50000
# 2/2 [==============================] - 2s 646ms/step - loss: 0.1022 - accuracy: 0.9616
# Epoch 5/50000
# 2/2 [==============================] - 2s 686ms/step - loss: 0.0975 - accuracy: 0.9619
# Epoch 6/50000
# 2/2 [==============================] - 2s 689ms/step - loss: 0.0986 - accuracy: 0.9619
# Epoch 7/50000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0991 - accuracy: 0.9619
# Epoch 8/50000
# 2/2 [==============================] - 2s 782ms/step - loss: 0.0987 - accuracy: 0.9619
# Epoch 9/50000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0974 - accuracy: 0.9619
# Epoch 10/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0954 - accuracy: 0.9619
# Epoch 11/50000
# 2/2 [==============================] - 2s 667ms/step - loss: 0.0938 - accuracy: 0.9619
# Epoch 12/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0905 - accuracy: 0.9619
# Epoch 13/50000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0843 - accuracy: 0.9619
# Epoch 14/50000
# 2/2 [==============================] - 2s 707ms/step - loss: 0.0781 - accuracy: 0.9619
# Epoch 15/50000
# 2/2 [==============================] - 2s 665ms/step - loss: 0.0734 - accuracy: 0.9619
# Epoch 16/50000
# 2/2 [==============================] - 2s 659ms/step - loss: 0.0696 - accuracy: 0.9619
# Epoch 17/50000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0675 - accuracy: 0.9605
# Epoch 18/50000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0663 - accuracy: 0.9584
# Epoch 19/50000
# 2/2 [==============================] - 2s 655ms/step - loss: 0.0656 - accuracy: 0.9583
# Epoch 20/50000
# 2/2 [==============================] - 2s 737ms/step - loss: 0.0658 - accuracy: 0.9583
# Epoch 21/50000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0655 - accuracy: 0.9583
# Epoch 22/50000
# 2/2 [==============================] - 2s 713ms/step - loss: 0.0656 - accuracy: 0.9583
# Epoch 23/50000
# 2/2 [==============================] - 2s 611ms/step - loss: 0.0654 - accuracy: 0.9583
# Epoch 24/50000
# 2/2 [==============================] - 2s 624ms/step - loss: 0.0651 - accuracy: 0.9595
# Epoch 25/50000
# 2/2 [==============================] - 2s 697ms/step - loss: 0.0648 - accuracy: 0.9619
# Epoch 26/50000
# 2/2 [==============================] - 2s 966ms/step - loss: 0.0644 - accuracy: 0.9619
# Epoch 27/50000
# 2/2 [==============================] - 2s 643ms/step - loss: 0.0641 - accuracy: 0.9619
# Epoch 28/50000
# 2/2 [==============================] - 2s 624ms/step - loss: 0.0639 - accuracy: 0.9619
# Epoch 29/50000
# 2/2 [==============================] - 2s 766ms/step - loss: 0.0639 - accuracy: 0.9619
# Epoch 30/50000
# 2/2 [==============================] - 2s 702ms/step - loss: 0.0637 - accuracy: 0.9619
# Epoch 31/50000
# 2/2 [==============================] - 2s 744ms/step - loss: 0.0637 - accuracy: 0.9619
# Epoch 32/50000
# 2/2 [==============================] - 2s 699ms/step - loss: 0.0636 - accuracy: 0.9619
# Epoch 33/50000
# 2/2 [==============================] - 2s 650ms/step - loss: 0.0635 - accuracy: 0.9619
# Epoch 34/50000
# 2/2 [==============================] - 2s 685ms/step - loss: 0.0633 - accuracy: 0.9619
# Epoch 35/50000
# 2/2 [==============================] - 2s 668ms/step - loss: 0.0632 - accuracy: 0.9619
# Epoch 36/50000
# 2/2 [==============================] - 2s 855ms/step - loss: 0.0630 - accuracy: 0.9619
# Epoch 37/50000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0629 - accuracy: 0.9619
# Epoch 38/50000
# 2/2 [==============================] - 2s 786ms/step - loss: 0.0627 - accuracy: 0.9619
# Epoch 39/50000
# 2/2 [==============================] - 2s 735ms/step - loss: 0.0626 - accuracy: 0.9619
# Epoch 40/50000
# 2/2 [==============================] - 2s 703ms/step - loss: 0.0625 - accuracy: 0.9619
# Epoch 41/50000
# 2/2 [==============================] - 2s 820ms/step - loss: 0.0624 - accuracy: 0.9619
# Epoch 42/50000
# 2/2 [==============================] - 2s 706ms/step - loss: 0.0624 - accuracy: 0.9619
# Epoch 43/50000
# 2/2 [==============================] - 2s 688ms/step - loss: 0.0624 - accuracy: 0.9619
# Epoch 44/50000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0623 - accuracy: 0.9619
# Epoch 45/50000
# 2/2 [==============================] - 2s 678ms/step - loss: 0.0624 - accuracy: 0.9619
# Epoch 46/50000
# 2/2 [==============================] - 2s 978ms/step - loss: 0.0620 - accuracy: 0.9619
# Epoch 47/50000
# 2/2 [==============================] - 2s 717ms/step - loss: 0.0625 - accuracy: 0.9619
# Epoch 48/50000
# 2/2 [==============================] - 2s 675ms/step - loss: 0.0623 - accuracy: 0.9619
# Epoch 49/50000
# 2/2 [==============================] - 2s 686ms/step - loss: 0.0625 - accuracy: 0.9619
# Epoch 50/50000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0624 - accuracy: 0.9619
# Epoch 51/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0622 - accuracy: 0.9619
# Epoch 52/50000
# 2/2 [==============================] - 2s 674ms/step - loss: 0.0622 - accuracy: 0.9619
# Epoch 53/50000
# 2/2 [==============================] - 2s 731ms/step - loss: 0.0619 - accuracy: 0.9619
# Epoch 54/50000
# 2/2 [==============================] - 2s 775ms/step - loss: 0.0619 - accuracy: 0.9619
# Epoch 55/50000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 56/50000
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 57/50000
# 2/2 [==============================] - 2s 672ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 58/50000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 59/50000
# 2/2 [==============================] - 2s 736ms/step - loss: 0.0616 - accuracy: 0.9619
# Epoch 60/50000
# 2/2 [==============================] - 2s 716ms/step - loss: 0.0623 - accuracy: 0.9619
# Epoch 61/50000
# 2/2 [==============================] - 2s 674ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 62/50000
# 2/2 [==============================] - 2s 960ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 63/50000
# 2/2 [==============================] - 2s 644ms/step - loss: 0.0616 - accuracy: 0.9619
# Epoch 64/50000
# 2/2 [==============================] - 2s 775ms/step - loss: 0.0619 - accuracy: 0.9619
# Epoch 65/50000
# 2/2 [==============================] - 2s 621ms/step - loss: 0.0617 - accuracy: 0.9619
# Epoch 66/50000
# 2/2 [==============================] - 2s 687ms/step - loss: 0.0620 - accuracy: 0.9619
# Epoch 67/50000
# 2/2 [==============================] - 2s 667ms/step - loss: 0.0616 - accuracy: 0.9619
# Epoch 68/50000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0619 - accuracy: 0.9619
# Epoch 69/50000
# 2/2 [==============================] - 2s 643ms/step - loss: 0.0616 - accuracy: 0.9619
# Epoch 70/50000
# 2/2 [==============================] - 2s 650ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 71/50000
# 2/2 [==============================] - 2s 701ms/step - loss: 0.0623 - accuracy: 0.9619
# Epoch 72/50000
# 2/2 [==============================] - 2s 700ms/step - loss: 0.0618 - accuracy: 0.9619
# Epoch 73/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0622 - accuracy: 0.9619
# Epoch 74/50000
# 2/2 [==============================] - 2s 636ms/step - loss: 0.0619 - accuracy: 0.9619
# Epoch 75/50000
# 2/2 [==============================] - 2s 685ms/step - loss: 0.0616 - accuracy: 0.9619
# Epoch 76/50000
# 2/2 [==============================] - 2s 768ms/step - loss: 0.0619 - accuracy: 0.9619
# Epoch 77/50000
# 2/2 [==============================] - 2s 719ms/step - loss: 0.0616 - accuracy: 0.9619
# Epoch 78/50000
# 2/2 [==============================] - 2s 707ms/step - loss: 0.0617 - accuracy: 0.9619
# Epoch 79/50000
# 2/2 [==============================] - 2s 825ms/step - loss: 0.0614 - accuracy: 0.9619
# Epoch 80/50000
# 2/2 [==============================] - 2s 744ms/step - loss: 0.0615 - accuracy: 0.9619
# Epoch 81/50000
# 2/2 [==============================] - 2s 825ms/step - loss: 0.0613 - accuracy: 0.9619
# Epoch 82/50000
# 2/2 [==============================] - 2s 714ms/step - loss: 0.0614 - accuracy: 0.9619
# Epoch 83/50000
# 2/2 [==============================] - 2s 761ms/step - loss: 0.0613 - accuracy: 0.9619
# Epoch 84/50000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0614 - accuracy: 0.9619
# Epoch 85/50000
# 2/2 [==============================] - 2s 760ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 86/50000
# 2/2 [==============================] - 2s 717ms/step - loss: 0.0614 - accuracy: 0.9619
# Epoch 87/50000
# 2/2 [==============================] - 2s 713ms/step - loss: 0.0613 - accuracy: 0.9619
# Epoch 88/50000
# 2/2 [==============================] - 2s 630ms/step - loss: 0.0614 - accuracy: 0.9619
# Epoch 89/50000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 90/50000
# 2/2 [==============================] - 2s 662ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 91/50000
# 2/2 [==============================] - 2s 700ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 92/50000
# 2/2 [==============================] - 2s 682ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 93/50000
# 2/2 [==============================] - 2s 628ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 94/50000
# 2/2 [==============================] - 2s 650ms/step - loss: 0.0613 - accuracy: 0.9619
# Epoch 95/50000
# 2/2 [==============================] - 2s 724ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 96/50000
# 2/2 [==============================] - 2s 668ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 97/50000
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 98/50000
# 2/2 [==============================] - 2s 676ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 99/50000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 100/50000
# 2/2 [==============================] - 2s 651ms/step - loss: 0.0610 - accuracy: 0.9619
# Epoch 101/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 102/50000
# 2/2 [==============================] - 2s 624ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 103/50000
# 2/2 [==============================] - 2s 631ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 104/50000
# 2/2 [==============================] - 2s 695ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 105/50000
# 2/2 [==============================] - 2s 734ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 106/50000
# 2/2 [==============================] - 2s 660ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 107/50000
# 2/2 [==============================] - 2s 657ms/step - loss: 0.0610 - accuracy: 0.9619
# Epoch 108/50000
# 2/2 [==============================] - 2s 692ms/step - loss: 0.0609 - accuracy: 0.9619
# Epoch 109/50000
# 2/2 [==============================] - 2s 662ms/step - loss: 0.0615 - accuracy: 0.9619
# Epoch 110/50000
# 2/2 [==============================] - 2s 667ms/step - loss: 0.0610 - accuracy: 0.9619
# Epoch 111/50000
# 2/2 [==============================] - 2s 1s/step - loss: 0.0614 - accuracy: 0.9619
# Epoch 112/50000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 113/50000
# 2/2 [==============================] - 2s 760ms/step - loss: 0.0608 - accuracy: 0.9619
# Epoch 114/50000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0615 - accuracy: 0.9619
# Epoch 115/50000
# 2/2 [==============================] - 2s 706ms/step - loss: 0.0608 - accuracy: 0.9619
# Epoch 116/50000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0615 - accuracy: 0.9619
# Epoch 117/50000
# 2/2 [==============================] - 2s 624ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 118/50000
# 2/2 [==============================] - 2s 675ms/step - loss: 0.0613 - accuracy: 0.9619
# Epoch 119/50000
# 2/2 [==============================] - 2s 613ms/step - loss: 0.0611 - accuracy: 0.9619
# Epoch 120/50000
# 2/2 [==============================] - 2s 692ms/step - loss: 0.0608 - accuracy: 0.9619
# Epoch 121/50000
# 2/2 [==============================] - 2s 716ms/step - loss: 0.0610 - accuracy: 0.9619
# Epoch 122/50000
# 2/2 [==============================] - 2s 706ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 123/50000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0609 - accuracy: 0.9619
# Epoch 124/50000
# 2/2 [==============================] - 2s 726ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 125/50000
# 2/2 [==============================] - 2s 628ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 126/50000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 127/50000
# 2/2 [==============================] - 2s 638ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 128/50000
# 2/2 [==============================] - 2s 656ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 129/50000
# 2/2 [==============================] - 2s 715ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 130/50000
# 2/2 [==============================] - 2s 665ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 131/50000
# 2/2 [==============================] - 2s 629ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 132/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 133/50000
# 2/2 [==============================] - 2s 714ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 134/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 135/50000
# 2/2 [==============================] - 2s 749ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 136/50000
# 2/2 [==============================] - 2s 678ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 137/50000
# 2/2 [==============================] - 2s 744ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 138/50000
# 2/2 [==============================] - 2s 736ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 139/50000
# 2/2 [==============================] - 2s 664ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 140/50000
# 2/2 [==============================] - 2s 731ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 141/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 142/50000
# 2/2 [==============================] - 2s 618ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 143/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 144/50000
# 2/2 [==============================] - 2s 671ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 145/50000
# 2/2 [==============================] - 2s 722ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 146/50000
# 2/2 [==============================] - 2s 608ms/step - loss: 0.0609 - accuracy: 0.9619
# Epoch 147/50000
# 2/2 [==============================] - 2s 652ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 148/50000
# 2/2 [==============================] - 2s 693ms/step - loss: 0.0608 - accuracy: 0.9619
# Epoch 149/50000
# 2/2 [==============================] - 2s 729ms/step - loss: 0.0609 - accuracy: 0.9619
# Epoch 150/50000
# 2/2 [==============================] - 2s 672ms/step - loss: 0.0608 - accuracy: 0.9619
# Epoch 151/50000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0612 - accuracy: 0.9619
# Epoch 152/50000
# 2/2 [==============================] - 2s 668ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 153/50000
# 2/2 [==============================] - 2s 663ms/step - loss: 0.0610 - accuracy: 0.9619
# Epoch 154/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 155/50000
# 2/2 [==============================] - 2s 710ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 156/50000
# 2/2 [==============================] - 2s 670ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 157/50000
# 2/2 [==============================] - 2s 711ms/step - loss: 0.0606 - accuracy: 0.9619
# Epoch 158/50000
# 2/2 [==============================] - 2s 633ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 159/50000
# 2/2 [==============================] - 2s 722ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 160/50000
# 2/2 [==============================] - 2s 627ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 161/50000
# 2/2 [==============================] - 2s 646ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 162/50000
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 163/50000
# 2/2 [==============================] - 2s 626ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 164/50000
# 2/2 [==============================] - 2s 659ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 165/50000
# 2/2 [==============================] - 2s 634ms/step - loss: 0.0605 - accuracy: 0.9619
# Epoch 166/50000
# 2/2 [==============================] - 2s 685ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 167/50000
# 2/2 [==============================] - 2s 725ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 168/50000
# 2/2 [==============================] - 2s 642ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 169/50000
# 2/2 [==============================] - 2s 646ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 170/50000
# 2/2 [==============================] - 2s 660ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 171/50000
# 2/2 [==============================] - 2s 655ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 172/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 173/50000
# 2/2 [==============================] - 2s 642ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 174/50000
# 2/2 [==============================] - 2s 736ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 175/50000
# 2/2 [==============================] - 2s 692ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 176/50000
# 2/2 [==============================] - 2s 681ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 177/50000
# 2/2 [==============================] - 2s 700ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 178/50000
# 2/2 [==============================] - 2s 672ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 179/50000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 180/50000
# 2/2 [==============================] - 2s 644ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 181/50000
# 2/2 [==============================] - 2s 631ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 182/50000
# 2/2 [==============================] - 2s 671ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 183/50000
# 2/2 [==============================] - 2s 718ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 184/50000
# 2/2 [==============================] - 2s 648ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 185/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 186/50000
# 2/2 [==============================] - 2s 709ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 187/50000
# 2/2 [==============================] - 2s 644ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 188/50000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 189/50000
# 2/2 [==============================] - 2s 697ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 190/50000
# 2/2 [==============================] - 2s 674ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 191/50000
# 2/2 [==============================] - 2s 626ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 192/50000
# 2/2 [==============================] - 2s 714ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 193/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 194/50000
# 2/2 [==============================] - 2s 660ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 195/50000
# 2/2 [==============================] - 2s 674ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 196/50000
# 2/2 [==============================] - 2s 618ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 197/50000
# 2/2 [==============================] - 2s 667ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 198/50000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 199/50000
# 2/2 [==============================] - 2s 665ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 200/50000
# 2/2 [==============================] - 2s 760ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 201/50000
# 2/2 [==============================] - 2s 711ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 202/50000
# 2/2 [==============================] - 2s 638ms/step - loss: 0.0598 - accuracy: 0.9619
# Epoch 203/50000
# 2/2 [==============================] - 2s 656ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 204/50000
# 2/2 [==============================] - 2s 622ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 205/50000
# 2/2 [==============================] - 2s 634ms/step - loss: 0.0598 - accuracy: 0.9619
# Epoch 206/50000
# 2/2 [==============================] - 2s 690ms/step - loss: 0.0598 - accuracy: 0.9619
# Epoch 207/50000
# 2/2 [==============================] - 2s 690ms/step - loss: 0.0598 - accuracy: 0.9619
# Epoch 208/50000
# 2/2 [==============================] - 2s 697ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 209/50000
# 2/2 [==============================] - 2s 707ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 210/50000
# 2/2 [==============================] - 2s 676ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 211/50000
# 2/2 [==============================] - 2s 665ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 212/50000
# 2/2 [==============================] - 2s 587ms/step - loss: 0.0607 - accuracy: 0.9619
# Epoch 213/50000
# 2/2 [==============================] - 2s 700ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 214/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0601 - accuracy: 0.9619
# Epoch 215/50000
# 2/2 [==============================] - 2s 675ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 216/50000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 217/50000
# 2/2 [==============================] - 2s 701ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 218/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 219/50000
# 2/2 [==============================] - 2s 654ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 220/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 221/50000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 222/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 223/50000
# 2/2 [==============================] - 2s 618ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 224/50000
# 2/2 [==============================] - 2s 896ms/step - loss: 0.0598 - accuracy: 0.9619
# Epoch 225/50000
# 2/2 [==============================] - 2s 648ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 226/50000
# 2/2 [==============================] - 2s 682ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 227/50000
# 2/2 [==============================] - 2s 643ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 228/50000
# 2/2 [==============================] - 2s 674ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 229/50000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 230/50000
# 2/2 [==============================] - 2s 682ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 231/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 232/50000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 233/50000
# 2/2 [==============================] - 2s 570ms/step - loss: 0.0602 - accuracy: 0.9619
# Epoch 234/50000
# 2/2 [==============================] - 2s 671ms/step - loss: 0.0604 - accuracy: 0.9619
# Epoch 235/50000
# 2/2 [==============================] - 2s 737ms/step - loss: 0.0600 - accuracy: 0.9619
# Epoch 236/50000
# 2/2 [==============================] - 2s 670ms/step - loss: 0.0603 - accuracy: 0.9619
# Epoch 237/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 238/50000
# 2/2 [==============================] - 2s 635ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 239/50000
# 2/2 [==============================] - 2s 620ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 240/50000
# 2/2 [==============================] - 2s 558ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 241/50000
# 2/2 [==============================] - 2s 674ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 242/50000
# 2/2 [==============================] - 2s 678ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 243/50000
# 2/2 [==============================] - 2s 639ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 244/50000
# 2/2 [==============================] - 2s 603ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 245/50000
# 2/2 [==============================] - 2s 720ms/step - loss: 0.0598 - accuracy: 0.9619
# Epoch 246/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 247/50000
# 2/2 [==============================] - 2s 696ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 248/50000
# 2/2 [==============================] - 2s 691ms/step - loss: 0.0599 - accuracy: 0.9619
# Epoch 249/50000
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 250/50000
# 2/2 [==============================] - 2s 627ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 251/50000
# 2/2 [==============================] - 2s 632ms/step - loss: 0.0597 - accuracy: 0.9619
# Epoch 252/50000
# 2/2 [==============================] - 2s 624ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 253/50000
# 2/2 [==============================] - 2s 621ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 254/50000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 255/50000
# 2/2 [==============================] - 2s 661ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 256/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 257/50000
# 2/2 [==============================] - 2s 677ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 258/50000
# 2/2 [==============================] - 2s 625ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 259/50000
# 2/2 [==============================] - 2s 640ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 260/50000
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 261/50000
# 2/2 [==============================] - 2s 735ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 262/50000
# 2/2 [==============================] - 2s 672ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 263/50000
# 2/2 [==============================] - 2s 644ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 264/50000
# 2/2 [==============================] - 2s 662ms/step - loss: 0.0593 - accuracy: 0.9619
# Epoch 265/50000
# 2/2 [==============================] - 2s 681ms/step - loss: 0.0593 - accuracy: 0.9619
# Epoch 266/50000
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0593 - accuracy: 0.9619
# Epoch 267/50000
# 2/2 [==============================] - 2s 696ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 268/50000
# 2/2 [==============================] - 2s 713ms/step - loss: 0.0593 - accuracy: 0.9619
# Epoch 269/50000
# 2/2 [==============================] - 2s 630ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 270/50000
# 2/2 [==============================] - 2s 672ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 271/50000
# 2/2 [==============================] - 2s 687ms/step - loss: 0.0593 - accuracy: 0.9619
# Epoch 272/50000
# 2/2 [==============================] - 2s 658ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 273/50000
# 2/2 [==============================] - 2s 702ms/step - loss: 0.0593 - accuracy: 0.9619
# Epoch 274/50000
# 2/2 [==============================] - 2s 694ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 275/50000
# 2/2 [==============================] - 2s 702ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 276/50000
# 2/2 [==============================] - 2s 737ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 277/50000
# 2/2 [==============================] - 2s 713ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 278/50000
# 2/2 [==============================] - 2s 649ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 279/50000
# 2/2 [==============================] - 2s 675ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 280/50000
# 2/2 [==============================] - 2s 659ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 281/50000
# 2/2 [==============================] - 2s 616ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 282/50000
# 2/2 [==============================] - 2s 680ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 283/50000
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 284/50000
# 2/2 [==============================] - 2s 651ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 285/50000
# 2/2 [==============================] - 2s 733ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 286/50000
# 2/2 [==============================] - 2s 629ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 287/50000
# 2/2 [==============================] - 2s 687ms/step - loss: 0.0590 - accuracy: 0.9619
# Epoch 288/50000
# 2/2 [==============================] - 2s 855ms/step - loss: 0.0590 - accuracy: 0.9619
# Epoch 289/50000
# 2/2 [==============================] - 2s 710ms/step - loss: 0.0590 - accuracy: 0.9619
# Epoch 290/50000
# 2/2 [==============================] - 2s 982ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 291/50000
# 2/2 [==============================] - 2s 681ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 292/50000
# 2/2 [==============================] - 2s 675ms/step - loss: 0.0589 - accuracy: 0.9619
# Epoch 293/50000
# 2/2 [==============================] - 2s 743ms/step - loss: 0.0590 - accuracy: 0.9619
# Epoch 294/50000
# 2/2 [==============================] - 2s 608ms/step - loss: 0.0590 - accuracy: 0.9619
# Epoch 295/50000
# 2/2 [==============================] - 2s 659ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 296/50000
# 2/2 [==============================] - 2s 639ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 297/50000
# 2/2 [==============================] - 2s 661ms/step - loss: 0.0589 - accuracy: 0.9619
# Epoch 298/50000
# 2/2 [==============================] - 2s 712ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 299/50000
# 2/2 [==============================] - 2s 682ms/step - loss: 0.0595 - accuracy: 0.9619
# Epoch 300/50000
# 2/2 [==============================] - 2s 613ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 301/50000
# 2/2 [==============================] - 2s 687ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 302/50000
# 2/2 [==============================] - 2s 732ms/step - loss: 0.0596 - accuracy: 0.9619
# Epoch 303/50000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0591 - accuracy: 0.9619
# Epoch 304/50000
# 2/2 [==============================] - 2s 728ms/step - loss: 0.0592 - accuracy: 0.9619
# Epoch 305/50000
# 2/2 [==============================] - 2s 734ms/step - loss: 0.0594 - accuracy: 0.9619
# Epoch 306/50000
# 2/2 [==============================] - 2s 754ms/step - loss: 0.0589 - accuracy: 0.9619
# Epoch 307/50000
# 2/2 [==============================] - 2s 850ms/step - loss: 0.0590 - accuracy: 0.9619
# Epoch 308/50000
# 2/2 [==============================] - 2s 736ms/step - loss: 0.0589 - accuracy: 0.9619
# Epoch 309/50000
# 2/2 [==============================] - 2s 721ms/step - loss: 0.0588 - accuracy: 0.9619
# Epoch 310/50000
# 2/2 [==============================] - 2s 769ms/step - loss: 0.0587 - accuracy: 0.9619
# Epoch 311/50000
# 2/2 [==============================] - 2s 833ms/step - loss: 0.0587 - accuracy: 0.9619
# Epoch 312/50000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 3
#       1 # fit the model of input_img to output_img (min 100.000 epochs)
#       2 epochs = 50000
# ----> 3 model.fit(input_img_array, output_img_array, epochs=epochs, shuffle=True)
#       5 # print out the computation time
#       6 finish=time.time()
#
# File c:\Users\marvi\miniconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marvi\miniconda3\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\marvi\miniconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# predict the original image as test image, 
# since it did not belong to the training data.
# if the domain was really adapted, then the result would look like output_img
print("output of test image")

model = tf.keras.models.load_model("domain_adapt_autoenc_epochs.50000.keras")
pred = model.predict(test_img_array)
plt.imshow(pred[0].reshape(SIZE,SIZE,3))
plt.show()
# Out:
# output of test image
# 1/1 [==============================] - 0s 218ms/step
